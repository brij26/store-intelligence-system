# %% [markdown]
# ### Load Video

# %%
import cv2

video_path = "data/raw/Store_1/CAM3-entry.mp4"

cap = cv2.VideoCapture(video_path)

print("FPS:", cap.get(cv2.CAP_PROP_FPS))
print("Width:", cap.get(cv2.CAP_PROP_FRAME_WIDTH))
print("Height:", cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
